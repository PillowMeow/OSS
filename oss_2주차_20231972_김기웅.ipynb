# %%
# 학번과 이름을 출력하세요
# 예시
# 학번 = '30261240'
# 이름 = '이현정'

학번 = '20231972'
이름 = '김기웅'

print(학번, 이름)
# Out:
# 20231972 김기웅

# %%
def factorial(n):
    """returns n!"""
    return 1 if n < 2 else n * factorial(n-1)

print(factorial(42))

print(factorial.__doc__)

print(type(factorial))
# Out:
# 1405006117752879898543142606244511569936384000000000
# returns n!
# <class 'function'>

# %%
help(factorial)
# Out:
# Help on function factorial in module __main__:
#
# factorial(n)
#     returns n!

# %%
fact = factorial
print(fact)
print(fact(5))
print(map(factorial, range(11)))

print(list(map(fact, range(11))))
# Out:
# <function factorial at 0x0000023E718AC040>
# 120
# <map object at 0x0000023E71896FC0>
# [1, 1, 2, 6, 24, 120, 720, 5040, 40320, 362880, 3628800]

# %%
fruits = ['strawberry', 'fig', 'apple', 'cherry', 'raspbrry', 'banana']
print(sorted(fruits, key=len))
# Out:
# ['fig', 'apple', 'cherry', 'banana', 'raspbrry', 'strawberry']

# %%
def reverse(word): return word[::-1]
print(reverse('testing'))


print(sorted(fruits, key=reverse))
# Out:
# gnitset
# ['banana', 'apple', 'fig', 'raspbrry', 'strawberry', 'cherry']

# %%
print(list(map(fact, range(6))))
print([fact(n) for n in range(6)])
print(list(map(factorial, filter(lambda n: n%2, range(6)))))
print([factorial(n) for n in range(6) if n % 2])
# Out:
# [1, 1, 2, 6, 24, 120]
# [1, 1, 2, 6, 24, 120]
# [1, 6, 120]
# [1, 6, 120]

# %%
print(sorted(fruits, key=lambda word: word[::-1]))
# Out:
# ['banana', 'apple', 'fig', 'raspbrry', 'strawberry', 'cherry']

# %%
print(abs, str, 13)
print([callable(obj) for obj in (abs, str, 13)])
# Out:
# <built-in function abs> <class 'str'> 13
# [True, True, False]

# %%
import random
class BingoCage:

    def __init__(self, items):
        self._items = list(items)
        random.shuffle(self._items)

    def pick(self):
        try:
            return self._items.pop()
        except:
            raise LookupError('pick from empyu BingoCage')
    
    def __call__(self):
        return self.pick()

# %%
bingo = BingoCage(range(3))
print(bingo.pick())

print(bingo())

print(callable(bingo))

print(bingo())
# Out:
# 2
# 0
# True
# 1

# %%
print(bingo())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 12, in BingoCage.pick(self)
#      10             return self._items.pop()
#      11         except:
# ---> 12             raise LookupError('pick from empyu BingoCage')
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(bingo())
#
# Cell In[11], line 15, in BingoCage.__call__(self)
#      14     def __call__(self):
# ---> 15         return self.pick()
#
# Cell In[11], line 12, in BingoCage.pick(self)
#       8     def pick(self):
#       9         try:
#      10             return self._items.pop()
#      11         except:
# ---> 12             raise LookupError('pick from empyu BingoCage')
#
# LookupError: pick from empyu BingoCage

# %%
def tag(name, *content, cls=None, **attrs):
    if cls is not None:
        attrs['class'] = cls
    if attrs:
        attr_str = ''.join(' %s="%s"' % (attr, value) for attr, value in sorted(attrs.items()))

    else:
        attr_str = ''
    if content:
        return '\n'.join('<%s%s>%s</%s>' % (name, attr_str, c, name) for c in content)

    else:
        return '<%s%s />' % (name, attr_str)

# %%
print(tag('br'))
print(tag('p', 'hello'))
print(tag('p', 'hello', 'world'))
print(tag('p', 'hello', id=33))
# Out:
# <br />
# <p>hello</p>
# <p>hello</p>
# <p>world</p>
# <p id="33">hello</p>

# %%
print(tag('p', 'hello', 'world', cls='sidebar'))
print(tag(content='testing', name='img'))
my_tag = {'name': 'img', 'title': 'Sunset Boulevard', 'src':'sunset.jpg', 'cls':'framed'}
print(tag(**my_tag))
# Out:
# <p class="sidebar">hello</p>
# <p class="sidebar">world</p>
# <img content="testing" />
# <img class="framed" src="sunset.jpg" title="Sunset Boulevard" />

# %%
def create_user(name, *, age, is_admin=False):
    print(f"Name: {name}, Age: {age}, Admin: {is_admin}")

create_user("Alice", age=30, is_admin=True)
create_user("Bob", 25)
# Out:
# Name: Alice, Age: 30, Admin: True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       1 def create_user(name, *, age, is_admin=False):
#       2     print(f"Name: {name}, Age: {age}, Admin: {is_admin}")
#       3
#       4 create_user("Alice", age=30, is_admin=True)
# ----> 5 create_user("Bob", 25)
#
# TypeError: create_user() takes 1 positional argument but 2 were given

# %%
def clip(text, max_len = 80):

    end = None
    if len(text) < max_len:
        space_before = text.rfind(' ', 0, max_len)
        if space_before >= 0:
            end = space_before
        else:
            space_after = text.rfind(' ', max_len)
            if space_after >= 0:
                end = space_after
        
    if end is None:
        end = len(text)
    return text[:end].rstrip()

# %%
print(clip.__defaults__)
print(clip.__code__)
print(clip.__code__.co_varnames)
print(clip.__code__.co_argcount)
# Out:
# (80,)
# <code object clip at 0x0000023E6FC908A0, file "C:\Users\kkw04\AppData\Local\Temp\ipykernel_25436\995517824.py", line 1>
# ('text', 'max_len', 'end', 'space_before', 'space_after')
# 2

# %%
from inspect import signature

sig = signature(clip)
print(sig)

print(str(sig))

for name, param in sig.parameters.items():
    print(param.kind, ":", name, "=", param.default)
# Out:
# (text, max_len=80)
# (text, max_len=80)
# POSITIONAL_OR_KEYWORD : text = <class 'inspect._empty'>
# POSITIONAL_OR_KEYWORD : max_len = 80

# %%
print(bound_args := sig.bind(**my_tag))

for name, value in bound_args.arguments.items():
    print(name, "=", value)

del my_tag['name']

print(bound_args := sig.bind(**my_tag))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(bound_args := sig.bind(**my_tag))
#       2
#       3 for name, value in bound_args.arguments.items():
#       4     print(name, "=", value)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\inspect.py:3236, in Signature.bind(self, *args, **kwargs)
#    3231 def bind(self, /, *args, **kwargs):
#    3232     """Get a BoundArguments object, that maps the passed `args`
#    3233     and `kwargs` to the function's signature.  Raises `TypeError`
#    3234     if the passed arguments can not be bound.
#    3235     """
# -> 3236     return self._bind(args, kwargs)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\inspect.py:3149, in Signature._bind(self, args, kwargs, partial)
#    3147                 msg = 'missing a required{argtype} argument: {arg!r}'
#    3148                 msg = msg.format(arg=param.name, argtype=argtype)
# -> 3149                 raise TypeError(msg) from None
#    3150 else:
#    3151     # We have a positional argument to process
#    3152     try:
#
# TypeError: missing a required argument: 'text'

# %%
def clip_fa(text: str, max_len: 'int > 0' = 80) -> str:

    end = None
    if len(text) < max_len:
        space_before = text.rfind(' ', 0, max_len)
        if space_before >= 0:
            end = space_before
        else:
            space_after = text.rfind(' ', max_len)
            if space_after >= 0:
                end = space_after
        
    if end is None:
        end = len(text)
    return text[:end].rstrip()

# %%
print(clip_fa.__annotations__)
# Out:
# {'text': <class 'str'>, 'max_len': 'int > 0', 'return': <class 'str'>}

# %%
sig2 = signature(clip_fa)
print(sig2.return_annotation)

for param in sig2.parameters.values():
    note = repr(param.annotation).ljust(13)
    print(note, ":", param.name, "=", param.default)
# Out:
# <class 'str'>
# <class 'str'> : text = <class 'inspect._empty'>
# 'int > 0'     : max_len = 80

# %%
from functools import reduce

def fact(n):
    return reduce(lambda a, b: a*b, range(1, n+1))
print(fact(10))
# Out:
# 3628800

# %%
from operator import mul
from functools import reduce

def fact(n):
    return reduce(mul, range(1, n+1))
print(fact(10))
# Out:
# 3628800

# %%
from operator import itemgetter

metro_data = [
    ('Tokyo', "JP", 36.933, (35.689722, 139.691667)),
    ('Delhi NCR', "IN", 21.935, (28.613389, 77.208889)),
    ('Mexico City', "MX", 20.142, (19.433333, -99.133333)),
    ('New York-Newark', "US", 20.104, (40.808611, -74.020386)),
    ('Sao Paulo', "BR", 19.649, (-23.547778, -46.635833))
]

for city in sorted(metro_data, key=itemgetter(1)):
    print(city)
# Out:
# ('Sao Paulo', 'BR', 19.649, (-23.547778, -46.635833))
# ('Delhi NCR', 'IN', 21.935, (28.613389, 77.208889))
# ('Tokyo', 'JP', 36.933, (35.689722, 139.691667))
# ('Mexico City', 'MX', 20.142, (19.433333, -99.133333))
# ('New York-Newark', 'US', 20.104, (40.808611, -74.020386))

# %%
cc_name = itemgetter(1, 0)
for city in metro_data:
    print(cc_name(city))
# Out:
# ('JP', 'Tokyo')
# ('IN', 'Delhi NCR')
# ('MX', 'Mexico City')
# ('US', 'New York-Newark')
# ('BR', 'Sao Paulo')

# %%
from collections import namedtuple
LatLong = namedtuple('LatLong', 'lat long')
Metropolis = namedtuple('Metropolis', 'name cc pop coord')
metro_areas = [Metropolis(name, cc, pop, LatLong(lat, long)) for name, cc, pop, (lat, long) in metro_data]

print(metro_areas[0])

print(metro_areas[0].coord.lat)

from operator import attrgetter
name_lat = attrgetter('name', 'coord.lat')

print(name_lat(metro_areas[0]))
# Out:
# Metropolis(name='Tokyo', cc='JP', pop=36.933, coord=LatLong(lat=35.689722, long=139.691667))
# 35.689722
# ('Tokyo', 35.689722)

# %%
for city in sorted(metro_areas, key=attrgetter('coord.lat')):
    print(name_lat(city))

metro_areas2 = [Metropolis(name, cc, pop, LatLong(*loc)) for name, cc, pop, loc in metro_data]
print(metro_areas2[0])
# Out:
# ('Sao Paulo', -23.547778)
# ('Mexico City', 19.433333)
# ('Delhi NCR', 28.613389)
# ('Tokyo', 35.689722)
# ('New York-Newark', 40.808611)
# Metropolis(name='Tokyo', cc='JP', pop=36.933, coord=LatLong(lat=35.689722, long=139.691667))

# %%
from operator import methodcaller
s = 'The time has come'
upcase = methodcaller('upper')

print(upcase(s))

print(s.upper())

hiphenate = methodcaller('replace', ' ', '-')
print(hiphenate(s))
# Out:
# THE TIME HAS COME
# THE TIME HAS COME
# The-time-has-come

# %%
from operator import mul
from functools import partial
triple = partial(mul, 3)
print(triple(7))

print(list(map(triple, range(1, 10))))
# Out:
# 21
# [3, 6, 9, 12, 15, 18, 21, 24, 27]

# %%
picture = partial(tag, 'img', cls='pic-frame')

print(picture(src='wumpus.jpg'))

print(tag, picture, picture.func, picture.args, picture.keywords)
# Out:
# <img class="pic-frame" src="wumpus.jpg" />
# <function tag at 0x0000023E719BFD70> functools.partial(<function tag at 0x0000023E719BFD70>, 'img', cls='pic-frame') <function tag at 0x0000023E719BFD70> ('img',) {'cls': 'pic-frame'}
